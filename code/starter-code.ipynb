# %% [markdown]
# # Project 1: Driving Licenses, Traffic Accidents and Casualties Analysis

# %% [markdown]
# ## Problem Statment
#
# Craft your problem statement here using the prompt from the README and other sources you find during your investigation.

# %% [markdown]
# Saudi Arabia recorded the highest death rate in traffic accidents in G20 country for traffic accidents and traffic accidents have become a leading cause of death for children and young people aged 5 to 29 years around the world, exceeding HIV and tuberculosis that show us how much we need to take action to reduce the number of accidents.

# %% [markdown]
# ## Executive Summary
# Write an executive summary that summarizes the problem and your key findings.

# %% [markdown]
# In this project we analysed the data so we can solve the problem that we have in Saudi Arabia that is the high number of accidents.
# From the data we can see that number of accidents in 2017 is less than 2016 and almost all the region have thier number of accidents decrease in 2017 or stayed similar to 2016 except Makkah increased almost 10000 accidents

# %% [markdown]
# ### Contents:
# - [Datasets Description](#Datasets-Description)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here, including any Jupyter magic commands*

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
sns.set(font_scale=1)
# %matplotlib inline

# %% [markdown]
# ## Datasets Description
#
# [Driving Licenses](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-driving-licenses-issued-in-the-kingdom-2004-2008/information/?disjunctive.administritive_area&sort=time_period&location=5,24.37495,45.08024&basemap=jawg.streets)
# This dataset contains Saudi Arabia Driving Licenses Issued By Administrative Area for 1993 - 2016. Data from General Authority for Statistics . Follow datasource.kapsarc.org for timely data to advance energy economics research.
#
# [Traffic Accidents and Casualties](https://datasource.kapsarc.org/explore/dataset/saudi-arabia-traffic-accidents-and-casualties-injured-dead-2008/export/?disjunctive.region&disjunctive.indicator&sort=time_period)
# This dataset contains Saudi Arabia Traffic Accidents and Casualties by Region for 2016. Data from General Authority for Statistics. Follow datasource.kapsarc.org for timely data to advance energy economics research.

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# #### 1. Read In Driving Licenses & Traffic Accidents Data
# Read in the `saudi-arabia-traffic-accidents-2008.csv` and `saudi-arabia-driving-licenses-2004-2008.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code
accidents = pd.read_csv('../data/saudi-arabia-traffic-accidents-2008.csv',delimiter=';')
licenses = pd.read_csv('../data/saudi-arabia-driving-licenses-2004-2008.csv',delimiter=';')

# %% [markdown]
# #### 2. Display data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code
accidents.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1    Year            Region  \
# 0           0             0  (2016)            Makkah
# 1           1             1  (2016)    Eastern Region
# 2           2             2  (2016)            Tabouk
# 3           3             3  (2016)              Hail
# 4           4             4  (2016)              Hail
# 5           5             5  (2016)  Northern Boarder
# 6           6             6  (2017)             Jazan
# 7           7             7  (2017)           Al-Jouf
# 8           8             8  (2017)             Total
# 9           9             9  (2016)  Northern Boarder
#
#                      Indicator   Value                  geo_point_2d
# 0  No. of Casualties - Injured  12383n   21.628962766, 41.2636898334
# 1     No. of Casualties - Dead   1113n  23.2883307307, 50.1478302439
# 2     No. of Casualties - Dead    434n    27.90165499, 37.2598581394
# 3     No. of Casualties - Dead    299n   27.400845724, 41.4406960508
# ...

# %%
licenses.head(10)
# Out:
#    Unnamed: 0    Year Administritive Area Driving Liceses  \
# 0           0  (2012)              Makkah         143954n
# 1           1  (1994)              Makkah          75349n
# 2           2  (1998)              Makkah          86082n
# 3           3  (2004)              Makkah          86636n
# 4           4  (2005)              Makkah          65099n
# 5           5  (2008)              Makkah          77013n
# 6           6  (2014)             Madinah          31447n
# 7           7  (2013)             Madinah          28513n
# 8           8  (2012)             Madinah          14459n
# 9           9  (1994)             Madinah           3767n
#
#                   geo_point_2d
# 0  21.628962766, 41.2636898334
# 1  21.628962766, 41.2636898334
# 2  21.628962766, 41.2636898334
# 3  21.628962766, 41.2636898334
# 4  21.628962766, 41.2636898334
# 5  21.628962766, 41.2636898334
# 6  24.927534539, 39.4918237173
# 7  24.927534539, 39.4918237173
# 8  24.927534539, 39.4918237173
# ...

# %% [markdown]
# #### 3. Briefly describe the data
#
# Take your time looking through the data and briefly describe the data in the markdown cell below. Note things about what the columns might mean, and the general information that is conveyed in the dataframe.

# %% [markdown]
# Answer:
# <div class="alert alert-block alert-info">
# There is two sets of data one for traffic accidents in Saudi Arabia (accidents) and the other one is for issued driving licenses in Saudi Arabia (licenses).
#
# And for the columns :
#
# year : reprsent the year when the data has been collected.
#
# region or adiministritive area : represents the where the data has been collected.
#
# geo_point_2d : represent the corredinate of the region.
#
# indictator in accidents : represent the result of the accident whether there is a casualties(dead or injured) or not.
#
# value in accidents : represent the number of the indicator
#
# driving_liceses : represent the number of issued driving licenses.

# %% [markdown]
# #### 4a. How complete is the data?
#
# Investigate missing values etc.

# %%
#Code
accidents.isnull().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# Year            0
# Region          0
# Indicator       0
# Value           0
# geo_point_2d    6
# dtype: int64

# %%
licenses.isnull().sum()
# Out:
# Unnamed: 0              0
# Year                    0
# Administritive Area     0
# Driving Liceses         0
# geo_point_2d           25
# dtype: int64

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each dataset? What is the maximum *possible* value?**

# %%
#Code
accidents.max()
# Out:
# Unnamed: 0                               83
# Unnamed: 0.1                             83
# Year                                 (2017)
# Region                                Total
# Indicator       No. of Casualties - Injured
# Value                                99925n
# dtype: object

# %%
licenses.max()
# Out:
# Unnamed: 0                349
# Year                   (2017)
# Administritive Area     Total
# Driving Liceses         9983n
# dtype: object

# %%
accidents.min()
# Out:
# Unnamed: 0                     0
# Unnamed: 0.1                   0
# Year                      (2016)
# Region                  Al-Baaha
# Indicator       No. of Accidents
# Value                      1007n
# dtype: object

# %%
licenses.min()
# Out:
# Unnamed: 0                   0
# Year                    (1993)
# Administritive Area    Al-Baha
# Driving Liceses        100291n
# dtype: object

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
# Unnamed: 0      84 non-null int64
# Unnamed: 0.1    84 non-null int64
# Year            84 non-null object
# Region          84 non-null object
# Indicator       84 non-null object
# Value           84 non-null object
# geo_point_2d    78 non-null object
# dtypes: int64(2), object(5)
# memory usage: 4.7+ KB

# %%
licenses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 5 columns):
# Unnamed: 0             350 non-null int64
# Year                   350 non-null object
# Administritive Area    350 non-null object
# Driving Liceses        350 non-null object
# geo_point_2d           325 non-null object
# dtypes: int64(1), object(4)
# memory usage: 13.8+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# <div class="alert alert-block alert-info">
# yes some of the columns type seem odd.
#
# for the accidents: the value and the year columns are not what they should be because the year column contain () and the the value contain n which make them object instead of int
#
# for the licenses: the driving liceses column contain n which make the column type object insted of int
#
# so we need to fix these data types

# %% [markdown]
# #### 6. Fix incorrect data types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert numerical columns to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
del accidents['Unnamed: 0']
del accidents['Unnamed: 0.1']
del licenses['Unnamed: 0']

# %%
#code
accidents['Value'] = accidents['Value'].apply(lambda x:x.strip('n')).astype(int)
accidents['Year'] = accidents['Year'].apply(lambda x:x.strip('()')).astype(int)

# %%
accidents.head()
# Out:
#    Year          Region                    Indicator  Value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383
# 1  2016  Eastern Region     No. of Casualties - Dead   1113
# 2  2016          Tabouk     No. of Casualties - Dead    434
# 3  2016            Hail     No. of Casualties - Dead    299
# 4  2016            Hail             No. of Accidents  10199
#
#                    geo_point_2d
# 0   21.628962766, 41.2636898334
# 1  23.2883307307, 50.1478302439
# 2    27.90165499, 37.2598581394
# 3   27.400845724, 41.4406960508
# 4   27.400845724, 41.4406960508

# %%
licenses['Year'] = licenses['Year'].apply(lambda x:x.strip('()')).astype(int)
licenses['Driving Liceses'] = licenses['Driving Liceses'].apply(lambda x:x.strip('n')).astype(int)

# %%
licenses.head()
# Out:
#    Year Administritive Area  Driving Liceses                 geo_point_2d
# 0  2012              Makkah           143954  21.628962766, 41.2636898334
# 1  1994              Makkah            75349  21.628962766, 41.2636898334
# 2  1998              Makkah            86082  21.628962766, 41.2636898334
# 3  2004              Makkah            86636  21.628962766, 41.2636898334
# 4  2005              Makkah            65099  21.628962766, 41.2636898334

# %% [markdown]
# - Make new columns `x` and `y` using `geo_point_2d`

# %%
#code
accidents[['x','y']] = accidents['geo_point_2d'].str.split(',',expand=True).apply(lambda x: x.str.strip())
licenses[['x','y']] = licenses['geo_point_2d'].str.split(',',expand=True).apply(lambda x: x.str.strip())

# %%
licenses.isnull().sum()
# Out:
# Year                    0
# Administritive Area     0
# Driving Liceses         0
# geo_point_2d           25
# x                      25
# y                      25
# dtype: int64

# %%
accidents.head()
# Out:
#    Year          Region                    Indicator  Value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383
# 1  2016  Eastern Region     No. of Casualties - Dead   1113
# 2  2016          Tabouk     No. of Casualties - Dead    434
# 3  2016            Hail     No. of Casualties - Dead    299
# 4  2016            Hail             No. of Accidents  10199
#
#                    geo_point_2d              x              y
# 0   21.628962766, 41.2636898334   21.628962766  41.2636898334
# 1  23.2883307307, 50.1478302439  23.2883307307  50.1478302439
# 2    27.90165499, 37.2598581394    27.90165499  37.2598581394
# 3   27.400845724, 41.4406960508   27.400845724  41.4406960508
# 4   27.400845724, 41.4406960508   27.400845724  41.4406960508

# %%
licenses.head()
# Out:
#    Year Administritive Area  Driving Liceses                 geo_point_2d  \
# 0  2012              Makkah           143954  21.628962766, 41.2636898334
# 1  1994              Makkah            75349  21.628962766, 41.2636898334
# 2  1998              Makkah            86082  21.628962766, 41.2636898334
# 3  2004              Makkah            86636  21.628962766, 41.2636898334
# 4  2005              Makkah            65099  21.628962766, 41.2636898334
#
#               x              y
# 0  21.628962766  41.2636898334
# 1  21.628962766  41.2636898334
# 2  21.628962766  41.2636898334
# 3  21.628962766  41.2636898334
# 4  21.628962766  41.2636898334

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
accidents['x'] = pd.to_numeric(accidents['x'],)
accidents['y'] = pd.to_numeric(accidents['y'])
licenses['x'] = pd.to_numeric(licenses['x'])
licenses['y'] = pd.to_numeric(licenses['y'])

# %%
licenses.isnull().sum()
# Out:
# Year                    0
# Administritive Area     0
# Driving Liceses         0
# geo_point_2d           25
# x                      25
# y                      25
# dtype: int64

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
# Year            84 non-null int32
# Region          84 non-null object
# Indicator       84 non-null object
# Value           84 non-null int32
# geo_point_2d    78 non-null object
# x               78 non-null float64
# y               78 non-null float64
# dtypes: float64(2), int32(2), object(3)
# memory usage: 4.0+ KB

# %%
licenses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
# Year                   350 non-null int32
# Administritive Area    350 non-null object
# Driving Liceses        350 non-null int32
# geo_point_2d           325 non-null object
# x                      325 non-null float64
# y                      325 non-null float64
# dtypes: float64(2), int32(2), object(2)
# memory usage: 13.8+ KB

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
display(accidents.dtypes)
# Out:
# Year              int32
# Region           object
# Indicator        object
# Value             int32
# geo_point_2d     object
# x               float64
# y               float64
# dtype: object

# %%
display(licenses.dtypes)
# Out:
# Year                     int32
# Administritive Area     object
# Driving Liceses          int32
# geo_point_2d            object
# x                      float64
# y                      float64
# dtype: object

# %% [markdown]
# #### 7. Rename columns
# Change the names of the columns to more expressive names so that you can tell the difference the Driving Licenses  columns and the & Traffic Accidents columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these two datasets, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).
# - Please also fix any typos you see in the column names.

# %%
#code
accidents = accidents.rename(columns={'Year':'year','Region':'region','Indicator':'indicator','Value':'value'})
licenses = licenses.rename(columns={'Year':'year','Administritive Area':'region','Driving Liceses':'driving_licenses'})

# %%
accidents.head()
# Out:
#    year          region                    indicator  value  \
# 0  2016          Makkah  No. of Casualties - Injured  12383
# 1  2016  Eastern Region     No. of Casualties - Dead   1113
# 2  2016          Tabouk     No. of Casualties - Dead    434
# 3  2016            Hail     No. of Casualties - Dead    299
# 4  2016            Hail             No. of Accidents  10199
#
#                    geo_point_2d          x          y
# 0   21.628962766, 41.2636898334  21.628963  41.263690
# 1  23.2883307307, 50.1478302439  23.288331  50.147830
# 2    27.90165499, 37.2598581394  27.901655  37.259858
# 3   27.400845724, 41.4406960508  27.400846  41.440696
# 4   27.400845724, 41.4406960508  27.400846  41.440696

# %%
licenses.head()
# Out:
#    year  region  driving_licenses                 geo_point_2d          x  \
# 0  2012  Makkah            143954  21.628962766, 41.2636898334  21.628963
# 1  1994  Makkah             75349  21.628962766, 41.2636898334  21.628963
# 2  1998  Makkah             86082  21.628962766, 41.2636898334  21.628963
# 3  2004  Makkah             86636  21.628962766, 41.2636898334  21.628963
# 4  2005  Makkah             65099  21.628962766, 41.2636898334  21.628963
#
#           y
# 0  41.26369
# 1  41.26369
# 2  41.26369
# 3  41.26369
# 4  41.26369

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**year**|*int*|accidents|The year of recorded data.|
# |**region**|*object*|accidents|The region where the data recorded |
# |**indicator**|*object*|accidents|Represent the types of accidents including types of Casualties(injured or dead) |
# |**value**|*int*|accidents|Represent the numbers of accidents including numbers of Casualties(injured or dead)|
# |**geo_point_2d**|*object*|accidents|The geographical coordinates of the region|
# |**x**|*float*|accidents|Represent x_coordinates of the region |
# |**y**|*float*|accidents|Represent y_coordinates of the region|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**year**|*int*|licenses|The year of recorded data.|
# |**region**|*object*|licenses|The region where the data recorded |
# |**driving_licenses**|*int*|licenses|The number of driving licenses issued|
# |**geo_point_2d**|*object*|licenses|The geographical coordinates of the region|
# |**x**|*float*|licenses|Represent x_coordinates of the region |
# |**y**|*float*|licenses|Represent y_coordinates of the region|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|Driving_Licenses/Traffic_Accidents|This is an example|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# This study concerns accident and license in regions/area. Please do the followings:
# 0. Which rows are not associated with regions?
# 1. Confirm the numbers of all regions add up to total.
# 2. Remove the rows that are not associated with regions

# %%
#code
accidents['region'].unique()
# Out:
# array(['Makkah', 'Eastern Region', 'Tabouk', 'Hail', 'Northern Boarder',
#        'Jazan', 'Al-Jouf', 'Total', 'Al-Baaha', 'Riyadh', 'Madinah',
#        'Qassim', 'Najran', 'Asir'], dtype=object)

# %%
licenses['region'].unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qaseem', 'Eastern', 'Assir', 'Tabouk',
#        'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Total', 'Riyadh'], dtype=object)

# %%
accidents_tot = accidents[accidents['region'] == 'Total']
accidents_tot.groupby(by=['year','indicator']).sum()
# Out:
#                                    value    x    y
# year indicator
# 2016 No. of Accidents             533380  0.0  0.0
#      No. of Casualties - Dead       9031  0.0  0.0
#      No. of Casualties - Injured   38120  0.0  0.0
# 2017 No. of Accidents             460488  0.0  0.0
#      No. of Casualties - Dead       7489  0.0  0.0
#      No. of Casualties - Injured   33199  0.0  0.0

# %%
accidents = accidents[accidents['region'] != 'Total']
accidents.groupby(by=['year','indicator']).sum()
# Out:
#                                    value           x           y
# year indicator
# 2016 No. of Accidents             533380  309.535811  553.836254
#      No. of Casualties - Dead       9031  309.535811  553.836254
#      No. of Casualties - Injured   38120  309.535811  553.836254
# 2017 No. of Accidents             460488  309.535811  553.836254
#      No. of Casualties - Dead       7489  309.535811  553.836254
#      No. of Casualties - Injured   33199  309.535811  553.836254

# %%
licenses_tot = licenses[licenses['region'] == 'Total']
licenses_tot.groupby(by=['year']).sum()
# Out:
#       driving_licenses    x    y
# year
# 1993            294893  0.0  0.0
# 1994            303520  0.0  0.0
# 1995            251878  0.0  0.0
# 1996            237623  0.0  0.0
# 1997            289296  0.0  0.0
# 1998            338350  0.0  0.0
# 1999            332210  0.0  0.0
# 2000            273238  0.0  0.0
# 2001            264725  0.0  0.0
# 2002            282038  0.0  0.0
# 2003            254858  0.0  0.0
# 2004            268738  0.0  0.0
# 2005            251203  0.0  0.0
# 2006            267508  0.0  0.0
# 2007            331356  0.0  0.0
# 2008            330158  0.0  0.0
# 2009            376275  0.0  0.0
# 2010            386510  0.0  0.0
# 2011            400558  0.0  0.0
# 2012            411204  0.0  0.0
# 2013            565314  0.0  0.0
# 2014            625414  0.0  0.0
# 2015            435439  0.0  0.0
# 2016            697017  0.0  0.0
# 2017            928165  0.0  0.0

# %%
licenses = licenses[licenses['region'] != 'Total']
licenses.groupby(by=['year']).sum()
# Out:
#       driving_licenses           x           y
# year
# 1993            294893  309.535811  553.836254
# 1994            303520  309.535811  553.836254
# 1995            251878  309.535811  553.836254
# 1996            237623  309.535811  553.836254
# 1997            289296  309.535811  553.836254
# 1998            338350  309.535811  553.836254
# 1999            332210  309.535811  553.836254
# 2000            273238  309.535811  553.836254
# 2001            264725  309.535811  553.836254
# 2002            282038  309.535811  553.836254
# 2003            254858  309.535811  553.836254
# 2004            268738  309.535811  553.836254
# 2005            251203  309.535811  553.836254
# 2006            267508  309.535811  553.836254
# 2007            331356  309.535811  553.836254
# 2008            330158  309.535811  553.836254
# 2009            376275  309.535811  553.836254
# 2010            386510  309.535811  553.836254
# 2011            400558  309.535811  553.836254
# ...

# %% [markdown]
# #### 10a. Data formats
# Is the License data in long or wide format? How about the Accident data? And why?

# %%
#code
licenses.head(10)
#the licenses data is in wide format
# Out:
#    year   region  driving_licenses                 geo_point_2d          x  \
# 0  2012   Makkah            143954  21.628962766, 41.2636898334  21.628963
# 1  1994   Makkah             75349  21.628962766, 41.2636898334  21.628963
# 2  1998   Makkah             86082  21.628962766, 41.2636898334  21.628963
# 3  2004   Makkah             86636  21.628962766, 41.2636898334  21.628963
# 4  2005   Makkah             65099  21.628962766, 41.2636898334  21.628963
# 5  2008   Makkah             77013  21.628962766, 41.2636898334  21.628963
# 6  2014  Madinah             31447  24.927534539, 39.4918237173  24.927535
# 7  2013  Madinah             28513  24.927534539, 39.4918237173  24.927535
# 8  2012  Madinah             14459  24.927534539, 39.4918237173  24.927535
# 9  1994  Madinah              3767  24.927534539, 39.4918237173  24.927535
#
#            y
# 0  41.263690
# 1  41.263690
# 2  41.263690
# 3  41.263690
# 4  41.263690
# 5  41.263690
# 6  39.491824
# 7  39.491824
# ...

# %%
accidents.head(10)
#The accidents data is in long format because of the indicator has variable:value
# Out:
#     year            region                    indicator  value  \
# 0   2016            Makkah  No. of Casualties - Injured  12383
# 1   2016    Eastern Region     No. of Casualties - Dead   1113
# 2   2016            Tabouk     No. of Casualties - Dead    434
# 3   2016              Hail     No. of Casualties - Dead    299
# 4   2016              Hail             No. of Accidents  10199
# 5   2016  Northern Boarder     No. of Casualties - Dead    193
# 6   2017             Jazan             No. of Accidents  22161
# 7   2017           Al-Jouf             No. of Accidents  10469
# 9   2016  Northern Boarder  No. of Casualties - Injured    631
# 10  2016             Jazan     No. of Casualties - Dead    514
#
#                     geo_point_2d          x          y
# 0    21.628962766, 41.2636898334  21.628963  41.263690
# 1   23.2883307307, 50.1478302439  23.288331  50.147830
# 2     27.90165499, 37.2598581394  27.901655  37.259858
# ...

# %% [markdown]
# #### 10b. Changing formats
# Which format would work best for both dataframes? Transform the datasets to the same format before merging in the next task.

# %%
#accidents.replace(to_replace=['Al-Baaha','Qassim','Eastern Region','Asir'],value=['Al-Baha','Al-Qaseem','Eastern','Assir'], inplace=True)

# %%
#code
# the wide format would be best for both
accidents = pd.pivot_table(accidents,index=["year","region",'x','y'],values="value",columns="indicator").reset_index()

# %%
accidents.head()
# Out:
# indicator  year   region          x          y  no_accidents  \
# 0          2016  Al-Baha  20.148406  41.466548          3618
# 1          2016  Al-Jouf  29.967745  39.557037         10212
# 2          2016    Assir  19.138785  42.941470         32684
# 3          2016  Eastern  23.288331  50.147830        101619
# 4          2016     Hail  27.400846  41.440696         10199
#
# indicator  no_casualties_dead  no_casualties_injured
# 0                         185                   1227
# 1                         245                    920
# 2                         983                   2541
# 3                        1113                   4893
# 4                         299                    932

# %%
accidents = accidents.rename(columns={'No. of Accidents':'no_accidents','No. of Casualties - Dead':'no_casualties_dead','No. of Casualties - Injured':'no_casualties_injured'})
accidents.head()
# Out:
# indicator  year   region          x          y  no_accidents  \
# 0          2016  Al-Baha  20.148406  41.466548          3618
# 1          2016  Al-Jouf  29.967745  39.557037         10212
# 2          2016    Assir  19.138785  42.941470         32684
# 3          2016  Eastern  23.288331  50.147830        101619
# 4          2016     Hail  27.400846  41.440696         10199
#
# indicator  no_casualties_dead  no_casualties_injured
# 0                         185                   1227
# 1                         245                    920
# 2                         983                   2541
# 3                        1113                   4893
# 4                         299                    932

# %% [markdown]
# #### 11. Merge dataframes
#
# Join the Driving Licenses & Traffic Accidents dataframes using the **region** and **year** in each dataframe as the key. Assign this to a new variable. Which join should you use to preserve the most data?

# %%
licenses.region.unique()
# Out:
# array(['Makkah', 'Madinah', 'Al-Qaseem', 'Eastern', 'Assir', 'Tabouk',
#        'Hail', 'Northern Boarder', 'Jazan', 'Najran', 'Al-Baha',
#        'Al-Jouf', 'Riyadh'], dtype=object)

# %%
#code
accidents.replace(to_replace=['Al-Baaha','Qassim','Eastern Region','Asir'],value=['Al-Baha','Al-Qaseem','Eastern','Assir'], inplace=True)

# %%
accidents.region.unique()
# Out:
# array(['Al-Baha', 'Al-Jouf', 'Assir', 'Eastern', 'Hail', 'Jazan',
#        'Madinah', 'Makkah', 'Najran', 'Northern Boarder', 'Al-Qaseem',
#        'Riyadh', 'Tabouk'], dtype=object)

# %%
combined = pd.merge(licenses, accidents, how='outer', on=['year','region','x','y'], sort=True)
combined
# Out:
#      year            region  driving_licenses                  geo_point_2d  \
# 0    1993           Al-Baha              3270  20.1484058503, 41.4665484892
# 1    1993           Al-Jouf              2884  29.9677445762, 39.5570371172
# 2    1993         Al-Qaseem             73618  26.1967063704, 43.3429998455
# 3    1993             Assir              6226   19.1387847401, 42.941470036
# 4    1993           Eastern              9964  23.2883307307, 50.1478302439
# 5    1993              Hail             10484   27.400845724, 41.4406960508
# 6    1993             Jazan              6009  17.2072313962, 42.6525807422
# 7    1993           Madinah              4122   24.927534539, 39.4918237173
# 8    1993            Makkah             65977   21.628962766, 41.2636898334
# 9    1993            Najran              3769  18.4511003068, 46.8688495726
# 10   1993  Northern Boarder              1510   30.197074783, 41.8171186952
# ...

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325 entries, 0 to 324
# Data columns (total 9 columns):
# year                     325 non-null int32
# region                   325 non-null object
# driving_licenses         325 non-null int32
# geo_point_2d             325 non-null object
# x                        325 non-null float64
# y                        325 non-null float64
# no_accidents             26 non-null float64
# no_casualties_dead       26 non-null float64
# no_casualties_injured    26 non-null float64
# dtypes: float64(5), int32(2), object(2)
# memory usage: 32.9+ KB

# %% [markdown]
# #### 12. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_datasets.csv`.

# %%
#code
combined.to_csv('..\data\combined_datasets.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
combined.describe().transpose()
# Out:
#                        count          mean           std          min  \
# year                   325.0   2005.000000      7.222222  1993.000000
# driving_licenses       325.0  28915.347692  47419.058819   915.000000
# x                      325.0     23.810447      4.197987    17.207231
# y                      325.0     42.602789      3.254196    37.259858
# no_accidents            26.0  38225.692308  46493.705035  1414.000000
# no_casualties_dead      26.0    635.384615    549.783381   112.000000
# no_casualties_injured   26.0   2743.038462   2922.641127   374.000000
#
#                                 25%           50%           75%            max
# year                    1999.000000   2005.000000   2011.000000    2017.000000
# driving_licenses        4846.000000  10267.000000  25423.000000  495307.000000
# x                         20.148406     23.288331     27.400846      30.197075
# y                         41.263690     41.817119     43.343000      50.147830
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def standev(df):
    df= df.dropna()
    columns = [column for column in df]
    mean = sum(columns)/len(columns)
    standev = (sum([(column - mean)**2 for column in columns]) / (len(df)))**(1/2)
    return standev

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'Driving_Licenses_x': 120, 'Traffic_Accidents_x': 120, ...}`

# %%
#Code:
combined_dict = {columns:standev(combined[columns]) for columns in combined if combined[columns].dtype != object}
combined_dict
# Out:
# {'year': 7.211102550927978,
#  'driving_licenses': 47346.05021744642,
#  'x': 4.191524025811858,
#  'y': 3.2491853051316926,
#  'no_accidents': 45590.82869880505,
#  'no_casualties_dead': 539.1069593406002,
#  'no_casualties_injured': 2865.8854113220236}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
np.std(combined)
# Out:
# year                         7.211103
# driving_licenses         47346.050217
# x                            4.191524
# y                            3.249185
# no_accidents             45590.828699
# no_casualties_dead         539.106959
# no_casualties_injured     2865.885411
# dtype: float64

# %% [markdown]
# Answer:
# <div class="alert alert-block alert-info">
# No, it didn't match excatly but it was very close
#
# and the diffrence because describe take sample where in the numpy's std take population

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which regions have the highest and lowest Driving Licenses based on years (1993 - 2017)
# - Which regions have the highest and lowest mean Traffic Accidents numbers for years (2016 - 2017)
# - What are the regions that have more Driving Licenses issued in each year than the year average?
# - What are the regions that have more Traffic Accidents happened in each year than the year average?
#
# Based on what you've just observed, have you identified any regions that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#code
combined[['year','region','driving_licenses']].sort_values('driving_licenses', ascending=False).head()
# Out:
#      year  region  driving_licenses
# 323  2017  Riyadh            495307
# 310  2016  Riyadh            242851
# 284  2014  Riyadh            194208
# 271  2013  Riyadh            165994
# 294  2015  Makkah            157389

# %% [markdown]
# **The region that have the highest driving licenses was Riyadh in 2017**

# %%
combined[['year','region','driving_licenses']].sort_values('driving_licenses').head()
# Out:
#      year            region  driving_licenses
# 298  2015            Tabouk               915
# 182  2007           Al-Baha               997
# 36   1995  Northern Boarder              1318
# 49   1996  Northern Boarder              1383
# 23   1994  Northern Boarder              1457

# %% [markdown]
# **The region that have the lowest driving licenses was Tabouk in 2015**

# %%
combined.groupby(by='region').mean().sort_values('no_accidents', ascending=False)['no_accidents'].head()
# Out:
# region
# Makkah       140189.5
# Riyadh       120830.5
# Eastern       91526.0
# Assir         28964.5
# Al-Qaseem     24034.5
# Name: no_accidents, dtype: float64

# %% [markdown]
# **The region that have the highest mean traffic accident was Makkah**

# %%
combined.groupby(by='region').mean().sort_values('no_accidents')['no_accidents'].head()
# Out:
# region
# Al-Baha              2516.0
# Najran               3214.0
# Hail                 9789.0
# Al-Jouf             10340.5
# Northern Boarder    12368.0
# Name: no_accidents, dtype: float64

# %% [markdown]
# **The region that have the lowest mean traffic accident was AL-Baha**

# %%
licenses_mean_year =combined.groupby(by='year', as_index = False).mean()[['year','driving_licenses']]
licenses_mean_year.columns = ['year','mean_year']

# %%
lic_m = pd.merge(licenses, licenses_mean_year, how='inner', on='year')
lic_m.head()
# Out:
#    year            region  driving_licenses                  geo_point_2d  \
# 0  2012            Makkah            143954   21.628962766, 41.2636898334
# 1  2012           Madinah             14459   24.927534539, 39.4918237173
# 2  2012  Northern Boarder              3706   30.197074783, 41.8171186952
# 3  2012           Eastern            129971  23.2883307307, 50.1478302439
# 4  2012             Assir             23136   19.1387847401, 42.941470036
#
#            x          y     mean_year
# 0  21.628963  41.263690  31631.076923
# 1  24.927535  39.491824  31631.076923
# 2  30.197075  41.817119  31631.076923
# 3  23.288331  50.147830  31631.076923
# 4  19.138785  42.941470  31631.076923

# %%
lic_year = lic_m[lic_m.driving_licenses > lic_m.mean_year][['year','region','driving_licenses','mean_year']]
lic_year.sort_values(by=['year','driving_licenses'], ascending=False)
# Out:
#      year     region  driving_licenses     mean_year
# 206  2017     Riyadh            495307  71397.307692
# 200  2017     Makkah            142487  71397.307692
# 198  2017    Eastern            126816  71397.307692
# 283  2016     Riyadh            242851  53616.692308
# 280  2016    Eastern            142307  53616.692308
# 276  2016     Makkah            136055  53616.692308
# 279  2016       Hail             54507  53616.692308
# 159  2015     Makkah            157389  33495.307692
# 156  2015    Eastern            135752  33495.307692
# 157  2015      Assir             38567  33495.307692
# 85   2014     Riyadh            194208  48108.769231
# 79   2014     Makkah            149234  48108.769231
# 87   2014    Eastern            121774  48108.769231
# 94   2013     Riyadh            165994  43485.692308
# 95   2013     Makkah            131108  43485.692308
# 98   2013    Eastern            123325  43485.692308
# 0    2012     Makkah            143954  31631.076923
# ...

# %% [markdown]
# **The regions that have the higher driving licenses issued in each year than the year average are in the output above**

# %%
accidents_mean_year = combined.groupby(by='year', as_index=False).mean()[['year','no_accidents']]
accidents_mean_year.columns = ['year','mean_year']

# %%
acc_m = pd.merge(accidents, accidents_mean_year, how='inner', on='year')
acc_m.head()
# Out:
#    year   region          x          y  no_accidents  no_casualties_dead  \
# 0  2016  Al-Baha  20.148406  41.466548          3618                 185
# 1  2016  Al-Jouf  29.967745  39.557037         10212                 245
# 2  2016    Assir  19.138785  42.941470         32684                 983
# 3  2016  Eastern  23.288331  50.147830        101619                1113
# 4  2016     Hail  27.400846  41.440696         10199                 299
#
#    no_casualties_injured     mean_year
# 0                   1227  41029.230769
# 1                    920  41029.230769
# 2                   2541  41029.230769
# 3                   4893  41029.230769
# 4                    932  41029.230769

# %%
acc_year = acc_m[acc_m.no_accidents > acc_m.mean_year][['year','region','no_accidents','mean_year']]
acc_year.sort_values(by=['year','no_accidents'], ascending=False)
# Out:
#     year   region  no_accidents     mean_year
# 20  2017   Makkah        145541  35422.153846
# 24  2017   Riyadh         99925  35422.153846
# 16  2017  Eastern         81433  35422.153846
# 11  2016   Riyadh        141736  41029.230769
# 7   2016   Makkah        134838  41029.230769
# 3   2016  Eastern        101619  41029.230769

# %% [markdown]
# **The regions that have the higher traffic acccidents in each year than the year average are in the output above**

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
combined.columns
# Out:
# Index(['year', 'region', 'driving_licenses', 'geo_point_2d', 'x', 'y',
#        'no_accidents', 'no_casualties_dead', 'no_casualties_injured'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(10,8))
sns.heatmap(combined[['year','region','driving_licenses','x','y','no_accidents',
                      'no_casualties_dead','no_casualties_injured']].corr(), annot=True)
plt.show()

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(figsize=(14,12), nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins=10) # feel free to add more settings
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Driving Licenses number
# - Traffic Accidents number
#
# Please plot two additional histograms that will help with your understanding of the data

# %%
# Code
subplot_histograms(combined, ['driving_licenses', 'no_accidents', 'no_casualties_dead', 'no_casualties_injured'],
                   ['driving licenses histogram','no_accidents histogram', 'no_casualties dead histogram', 'no_casualties injured histogram'],
                  ['driving_licenses', 'no_accidents', 'no_casualties_dead', 'no_Casualties_injured'])
plt.tight_layout
# Out:
# C:\Users\Talal\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Talal\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - Driving Licenses vs. Traffic Accidents for 2017
# - Driving Licenses vs. Traffic Accidents for 2016
# - Driving Licenses for 2016 vs 2017
# - Traffic Accidents for 2016 vs 2017
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code
plt.scatter(combined.no_accidents[combined.year == 2017],combined.driving_licenses[combined.year == 2017], c='red', marker='x', s=150)
plt.ylabel('Driving Licenses 2017')
plt.xlabel('Traffic Accidents 2017')
plt.title('Driving Licenses vs. Traffic Accidents 2017',fontdict= {'size':14})
plt.show()

# %%
plt.scatter(combined.no_accidents[combined.year == 2016],combined.driving_licenses[combined.year == 2016], c='red', marker='x', s=150)
plt.ylabel('Driving Licenses 2016')
plt.xlabel('Traffic Accidents 2016')
plt.title('Driving Licenses vs. Traffic Accidents 2016',fontdict= {'size':14})
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(combined.driving_licenses[combined.year == 2016],combined.driving_licenses[combined.year == 2017], c='red', marker='x', s=150)
plt.ylabel('Driving Licenses 2016')
plt.xlabel('Driving Licenses 2017')
plt.title('Driving Licenses 2016 vs. Driving Licenses 2017',fontdict= {'size':14})
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(combined.no_accidents[combined.year == 2016],combined.no_accidents[combined.year == 2017], c='red', marker='x', s=150)
plt.ylabel('Traffic Accidents 2016')
plt.xlabel('Traffic Accidents 2017')
plt.title('Traffic Accidents vs. Traffic Accidents 2017',fontdict= {'size':14})
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.boxplot('driving_licenses', data=combined, orient='h',
                fliersize=10, linewidth=1.5, notch=False,
                saturation=1, ax=ax)

ax.set_title('Driving Licenses\n', fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.boxplot('no_accidents', data=combined, orient='h',
                fliersize=10, linewidth=1.5, notch=False,
                saturation=1, ax=ax)

ax.set_title('No_Accidents\n', fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.boxplot('no_casualties_dead', data=combined, orient='h',
                fliersize=10, linewidth=1.5, notch=False,
                saturation=1, ax=ax)

ax.set_title('No_Casualties_dead\n', fontsize=15)

plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.boxplot('no_casualties_injured', data=combined, orient='h',
                fliersize=10, linewidth=1.5, notch=False,
                saturation=1, ax=ax)

ax.set_title('No_Casualties_injured\n', fontsize=15)

plt.show()

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
plt.figure(figsize=(40,15)) 
x=sns.swarmplot(x='year', y='driving_licenses', data = combined, hue='region', s=12)
x.legend(loc=2, bbox_to_anchor=(1, 1))
x.set_title('diving licenses for each region per year', fontdict= {'size':30})
# Out:
# Text(0.5, 1.0, 'diving licenses for each region per year')

# %%
plt.figure(figsize=(20,10)) 
sns.barplot(x='region', y='no_accidents', hue='year', data=combined[combined.year > 2015])

# %%
plt.figure(figsize=(20,10)) 
sns.barplot(x='region', y='driving_licenses', hue='year', data=combined[combined.year > 2015])

# %%
plt.figure(figsize=(20,15)) 
x=sns.swarmplot(y='no_accidents', x='driving_licenses', data = combined[combined.year==2016], hue='region', s=20)
x.legend(loc=2, bbox_to_anchor=(1, 1))
x.set_title('diving licenses vs no_accidents 2016', fontdict= {'size':32})
# Out:
# Text(0.5, 1.0, 'diving licenses vs no_accidents 2016')

# %%
plt.figure(figsize=(20,15)) 
x=sns.swarmplot(y='no_accidents', x='driving_licenses', data = combined[combined.year==2017], hue='region', s=20)
x.legend(loc=2, bbox_to_anchor=(1, 1))
x.set_title('diving licenses vs no_accidents 2017', fontdict= {'size':32})
# Out:
# Text(0.5, 1.0, 'diving licenses vs no_accidents 2017')

# %%
plt.figure(figsize=(34,15)) 
x=sns.swarmplot(y='no_accidents', x='driving_licenses', data = combined[combined.year>2015], hue='region', s=20)
x.legend(loc=2, bbox_to_anchor=(1, 1))
x.set_title('diving licenses vs no_accidents', fontdict= {'size':32})
# Out:
# Text(0.5, 1.0, 'diving licenses vs no_accidents')

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
combined.describe()
# Out:
#               year  driving_licenses           x           y   no_accidents  \
# count   325.000000        325.000000  325.000000  325.000000      26.000000
# mean   2005.000000      28915.347692   23.810447   42.602789   38225.692308
# std       7.222222      47419.058819    4.197987    3.254196   46493.705035
# min    1993.000000        915.000000   17.207231   37.259858    1414.000000
# 25%    1999.000000       4846.000000   20.148406   41.263690   10276.250000
# 50%    2005.000000      10267.000000   23.288331   41.817119   16050.500000
# 75%    2011.000000      25423.000000   27.400846   43.343000   30981.250000
# max    2017.000000     495307.000000   30.197075   50.147830  145541.000000
#
#        no_casualties_dead  no_casualties_injured
# count           26.000000              26.000000
# mean           635.384615            2743.038462
# std            549.783381            2922.641127
# min            112.000000             374.000000
# ...

# %%
combined.skew()
# Out:
# year                     0.000000
# driving_licenses         4.177206
# x                        0.020839
# y                        0.714937
# no_accidents             1.486476
# no_casualties_dead       1.406080
# no_casualties_injured    2.302753
# dtype: float64

# %%
combined.median()
# Out:
# year                      2005.000000
# driving_licenses         10267.000000
# x                           23.288331
# y                           41.817119
# no_accidents             16050.500000
# no_casualties_dead         415.500000
# no_casualties_injured     1618.500000
# dtype: float64

# %% [markdown]
# Answers:
# <div class="alert alert-block alert-info">
#
# **driving_licenses:**
#
# mean = 28915.347692, median = 10267.000000 and skew = 4.177206
#
# so from the distribution, central tendency and skew we conclude that the distribution highly skewed to the right indicates that the size of the right-handed tail is larger than the left-handed tail.
#
# **no_accidents:**
#
# mean = 38225.692308, median = 16050.500000 and skew = 1.486476
#
# so from the distribution, central tendency and skew we conclude that the distribution highly skewed to the right indicates that the size of the right-handed tail is larger than the left-handed tail.
#
# **no_casualties_dead:**
#
# mean = 635.384615, median = 415.500000 and skew = 1.406080
#
# so from the distribution, central tendency and skew we conclude that the distribution highly skewed to the right indicates that the size of the right-handed tail is larger than the left-handed tail.
#
# **no_casualties_injured:**
#
# mean = 2743.038462, median = 1618.500000 and skew = 2.302753
#
# so from the distribution, central tendency and skew we conclude that the distribution highly skewed to the right indicates that the size of the right-handed tail is larger than the left-handed tail.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer:
# <div class="alert alert-block alert-info">
# No, we don't

# %% [markdown]
# Does This Assumption Hold for:
#     - Driving Licenses
#     - Traffic Accidents
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# Answer:
# <div class="alert alert-block alert-info">
#
# Since all the distributions are highly skewed to the right then i'm going to comment on all them at once:
#
# The normal distribution is easiest way to understand the data but since our distributions are skewed (too much skewness) so most of the common statistical methods won't work.
#
# As result we need more data to reduce the skewness

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code
from scipy.stats import normaltest

# %%
test_stat = combined[['driving_licenses','no_accidents','no_casualties_dead','no_casualties_injured']]

# %%
for c in test_stat:
    z,p = normaltest(test_stat[c].dropna())
    print('\n'+c+'\n')
    print('z-score = ', z, 'p-value = ', p)
    if p > 0.05:
        print('since the p-value > 0.05 then it is failed to reject the null hypothesis')
    else:
        print('since the p-value < 0.05 then it is rejecting the null hypthesis')
# Out:
# driving_licenses
#
# z-score =  325.6344141041676 p-value =  1.9470872744852377e-71
# since the p-value < 0.05 then it is rejecting the null hypthesis
#
# no_accidents
#
# z-score =  9.604128228241276 p-value =  0.00821277743156539
# since the p-value < 0.05 then it is rejecting the null hypthesis
#
# no_casualties_dead
#
# z-score =  10.469759063899353 p-value =  0.005327466234634826
# since the p-value < 0.05 then it is rejecting the null hypthesis
#
# no_casualties_injured
#
# z-score =  25.490999951788222 p-value =  2.9154103508906527e-06
# since the p-value < 0.05 then it is rejecting the null hypthesis

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** regions that demonstrate interesting trends in the number of driving licenses and traffic accidents. Spend some time doing outside research on provincial and central policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
plt.figure(figsize=(18,6)) 
x=sns.swarmplot(y='no_accidents', x='driving_licenses', data = combined[combined.year>2015], hue='region', s=20)
x.legend(loc=2, bbox_to_anchor=(1, 1))
x.set_title('diving licenses vs no_accidents', fontdict= {'size':32})
# Out:
# Text(0.5, 1.0, 'diving licenses vs no_accidents')

# %%
plt.figure(figsize=(10,6)) 
x=sns.swarmplot(y='no_accidents', x='driving_licenses', data = combined[combined.year==2016], hue='region', s=20)
x.legend(loc=2, bbox_to_anchor=(1, 1))
x.set_title('diving licenses vs no_accidents 2016', fontdict= {'size':32})
# Out:
# Text(0.5, 1.0, 'diving licenses vs no_accidents 2016')

# %%
plt.figure(figsize=(10,6)) 
x=sns.swarmplot(y='no_accidents', x='driving_licenses', data = combined[combined.year==2017], hue='region', s=20)
x.legend(loc=2, bbox_to_anchor=(1, 1))
x.set_title('diving licenses vs no_accidents 2017', fontdict= {'size':32})
# Out:
# Text(0.5, 1.0, 'diving licenses vs no_accidents 2017')

# %%
plt.figure(figsize=(20,10)) 
sns.barplot(x='region', y='no_accidents', hue='year', data=combined[combined.year > 2015])

# %%
plt.figure(figsize=(20,10)) 
sns.barplot(x='year', y='no_accidents', data=combined[combined.year > 2015])

# %% [markdown]
# Answer:
# <div class="alert alert-block alert-info">
#
# From the plots we made we can see that the 3 regions with the highest no_accidents have the highest driving licenses issued.
# and they are Riyadh, Makkah and Eastern.
#
# also we can see that the number of accidents in Riyadh and Eastern decrease significantly in 2017, and the reason for it is because in 2016 The General Department of Traffic started new penalties according to saudi gazette "The Traffic Department will not show any leniency in implementing new regulations, especially Article 69 of the law pertaining to drifting/stunt driving, said Director of the Traffic Department Maj. Gen. Abdullah Al-Zahrani"(http://saudigazette.com.sa/article/160982).
#
# and for Makkah the reason why the number of accidents didn't decrease it's probably because Makkah had the highest number of violations in all regions.(according to the data in general general authority for statistics(https://www.stats.gov.sa/en/6008)).

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# - Based on your exploration of the data, what are you key takeaways and recommendations?
# - Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# Answer:
# <div class="alert alert-block alert-info">
#
# What can we recommend from the exploration of the data and outside research is that:
#
# 1.From the outside research we saw that the new penalties implemented in 2016 has a positive affect on number of accidents in 2017
#
# 2.And for Makkah we saw the new penalties didn't reduced the number of accidents, and as i mentioned before according to the data in general general authority for statistics(https://www.stats.gov.sa/en/6008) we see that number of violations in makkah is significantly higher than any region so at the moment we recommend awareness campaign in schools or in the street also we can use social media which proved to be affective in reaching and influence people.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Yes we need more data to give more and better recommendations.
#
# Examples for data we desire like:
#
# 1.The cause of accidents(speed violations, road design,etc...).
#
# 2.Where the accidents happened inside or outside the city to help us with the The cause of accidents to give more efficient rocmmendations.
#
# 3.Since women didn't drive until jun-2018 so i recommend we add gender for future data so we can know who has the higher number of accidents or the cause of it.
